# %% [markdown]
# <center><img src="img/logo_hse_black.jpg"></center>
#
# <h1><center>Data Analysis</center></h1>
# <h2><center>Homewrok: Neural Networks 2</center></h2>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
import tensorflow.python.framework.dtypes
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Convolution2D, MaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras import initializers
from tensorflow.keras.preprocessing.image import ImageDataGenerator


RND_SEED = 7
np.random.seed(RND_SEED)

# %matplotlib inline

# %% [markdown]
# # Intro
#
# For this homework you are propossed to
# 1. implement autoencoder model based on Keras library using MNIST sample.
# 2. set up your own dataset for transfer learning and apply pretrained model

# %% [markdown]
# # Autoencoders

# %% [markdown]
# Idea of autoencoders is illustrated in the following figure:
# <center><img src='img/autoencoder_schema.jpg'></center>
#
# Autoencoder consists of two parts: encoder and decoder.
# Encoder takes an image and encodes it into another image or vector with smaller size. In other words, it compresses the image. On the other hand, decoder takes the compressed image and reconstructs the original image. If the autoencoder is designed and fitted properly, the original and reconstructed images will be similar.

# %% [markdown]
# # Fully-connected Autoencoder

# %% [markdown]
# Consider an autoencoder which consists only fully-connected layers (no convolutions, no pooling et al.) as it is show in figure:
#
# <center><img src='img/ae.png'></center>
#
# This autoencoder takes an image as a vector and encodes it into a vector of smaller size. Its output is a reconstructed image represented as a vector of the same size as the input.

# %% [markdown]
# ## Task 1 (1 point)
#
# Download and read MNIST sample. Plot several images. Do all preprocessing steps needed for the autoencoder.
#
# Hint: use `from tensorflow.keras.datasets import mnist`

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data() # dwonload and read MNIST sample
n_train, img_rows, img_cols = X_train.shape
n_test, _, _ = X_test.shape
plt.figure(figsize=(6,6))
x, y = 3, 3
for i in range(x*y):  
    plt.subplot(y, x, i+1)
    plt.imshow(X_train[i], cmap=plt.cm.gray_r, interpolation='nearest')
plt.tight_layout()
plt.show()

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
n_classes = 10
X_train /= 255
X_test /= 255
y_train_hot = to_categorical(y_train, n_classes)
y_test_hot = to_categorical(y_test, n_classes)

# %% [markdown]
# ## Task 2 (3 points)
#
# Implement your autoencoder using Keras library with the following structure:
# - **Encoder** has one fully-connected layer, that compresses an input image into a vector of size 49.
# - **Decoder** has one fully-connected layer, that reconstructs the original image.
#
# Fit your autoencoder during 5 epochs. Use **mse** error function.
#
# Hint: see Keras examples from your seminars.

# %%
X_train_nn = X_train.reshape((n_train, -1, ))
X_test_nn = X_test.reshape((n_test, -1, ))

print('X_train:    ', X_train.shape)
print('X_train_nn: ', X_train_nn.shape)

model = Sequential() # init NN model
model.add(Dense(49, input_shape=X_train_nn[0].shape,bias_initializer= initializers.Zeros(), 
                kernel_initializer='normal', activation='sigmoid'))
model.add(Dense(X_train_nn[0].shape[0], activation='softmax'))

# Compile model
model.compile(loss='mse', optimizer='adam')
# Out:
# X_train:     (60000, 28, 28)
# X_train_nn:  (60000, 784)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 49)                38465
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               39200
# =================================================================
# Total params: 77,665
# Trainable params: 77,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train_nn, X_train_nn, epochs=5, validation_data=(X_test_nn, X_test_nn))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 75us/sample - loss: 0.1103 - val_loss: 0.1119
# Epoch 2/5
# 60000/60000 [==============================] - 4s 70us/sample - loss: 0.1099 - val_loss: 0.1118
# Epoch 3/5
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.1099 - val_loss: 0.1118
# Epoch 4/5
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1099 - val_loss: 0.1118
# Epoch 5/5
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.1098 - val_loss: 0.1117

# %% [markdown]
# ## Task 3 (1 point)
#
# Test your autoencoder. Calculate MSE error between inputs and outputs of the autoencoder. Plot several input and output images. Are they similar?

# %%
labels = ["Mnist data", "Output"]
datasets = [X_test, model.predict(X_test_nn).reshape(X_test.shape)]
columns = len(datasets)
rows = 5
_, ax = plt.subplots(rows, columns, sharex=True, figsize=(rows*columns, rows * 2))
for i in range(rows):
    for j in range(columns):
        subplot = ax[i] if (columns == 1) else ax[i, j]
        if (i == 0):
            subplot.set_title(labels[j])
        subplot.imshow(datasets[j][i])  
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# In this task you should construct your own dataset to perform classification or regression task.
# For instance you can
# * Predict age (age group) given face image
# * Classify different types of vehicles on the image
# * Classify smartphone models
# * [Your Idea Here]

# %% [raw]
# Write down your task:

# %% [markdown]
# ## Task 4 (3 points)
#
# Construct your dataset
# * It should be you handmade raw dataset (not loaded completely in the web by someone else)
# * It should contain at least 500 images (the more - the better)
# * Once collected it should be downloadable via `wget` command in terminal (if you have windows you can check it in Google Collab) - for instance use dropbox or Yandex.Disk to get the link
#
# Helpful links: [1](https://www.pyimagesearch.com/2018/04/09/how-to-quickly-build-a-deep-learning-image-dataset/), [2](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)

# %%
# !wget https://www.dropbox.com/s/mvofm4m2qjpe66v/out1.zip?dl=0 -O out1.zip
# Out:
# --2020-05-25 15:33:00--  https://www.dropbox.com/s/mvofm4m2qjpe66v/out1.zip?dl=0
# Распознаётся www.dropbox.com (www.dropbox.com)… 162.125.70.1, 2620:100:6026:1::a27d:4601
# Подключение к www.dropbox.com (www.dropbox.com)|162.125.70.1|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 301 Moved Permanently
# Адрес: /s/raw/mvofm4m2qjpe66v/out1.zip [переход]
# --2020-05-25 15:33:01--  https://www.dropbox.com/s/raw/mvofm4m2qjpe66v/out1.zip
# Повторное использование соединения с www.dropbox.com:443.
# HTTP-запрос отправлен. Ожидание ответа… 302 Found
# Адрес: https://uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com/cd/0/inline/A4bf5aj7x4a_Yb83ZlwG7Rv21sxf5Fb6vzEM1GwUQ7P6AkuE0mywlFS6_j-ZX_brP08kFPIJNUGlN-XwOZtDVJiUhlSm4xdEniA8ISm0C91p52RjhxbxiGep1ormABsUUUc/file# [переход]
# --2020-05-25 15:33:01--  https://uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com/cd/0/inline/A4bf5aj7x4a_Yb83ZlwG7Rv21sxf5Fb6vzEM1GwUQ7P6AkuE0mywlFS6_j-ZX_brP08kFPIJNUGlN-XwOZtDVJiUhlSm4xdEniA8ISm0C91p52RjhxbxiGep1ormABsUUUc/file
# Распознаётся uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com (uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com)… 162.125.70.6, 2620:100:6026:6::a27d:4606
# Подключение к uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com (uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com)|162.125.70.6|:443... соединение установлено.
# HTTP-запрос отправлен. Ожидание ответа… 302 FOUND
# Адрес: /cd/0/inline2/A4Z7QVC_FHpCLGOTJLquRL06yVeBprpOZf5UAYk6HEFnaNMN-ZzxfxyzmUN84TM0zmhUnkzVhVAOkM9Zsm-8nmw0MTs5tWQTBMqgQYXWW--35AeUrb_T_2O_FHf1WJ24PbNZtuOqorW7epWy0XItwOO2EF13twwvznMeIFnQ-aBzOqLuh8S2mUlqbhT8HZG8-jZoLSVl8piIMhiErWBZ4901MLDod2cmeqwvTZEdCdTU-izVTX9MYlbuYxxqOAGztUVR9vzMSXbFN_zVie1ZlBKW61N4u7liFpxHog6tFPJLBT_3nQVlU1vbZKOijjR9Yah3TlHKBdmjBqx0nyXXhdJNXz2Be-VyrzAkS-KTBJMn6Q/file [переход]
# --2020-05-25 15:33:02--  https://uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com/cd/0/inline2/A4Z7QVC_FHpCLGOTJLquRL06yVeBprpOZf5UAYk6HEFnaNMN-ZzxfxyzmUN84TM0zmhUnkzVhVAOkM9Zsm-8nmw0MTs5tWQTBMqgQYXWW--35AeUrb_T_2O_FHf1WJ24PbNZtuOqorW7epWy0XItwOO2EF13twwvznMeIFnQ-aBzOqLuh8S2mUlqbhT8HZG8-jZoLSVl8piIMhiErWBZ4901MLDod2cmeqwvTZEdCdTU-izVTX9MYlbuYxxqOAGztUVR9vzMSXbFN_zVie1ZlBKW61N4u7liFpxHog6tFPJLBT_3nQVlU1vbZKOijjR9Yah3TlHKBdmjBqx0nyXXhdJNXz2Be-VyrzAkS-KTBJMn6Q/file
# Повторное использование соединения с uc53b2469ca081e8ad7597f5fb14.dl.dropboxusercontent.com:443.
# HTTP-запрос отправлен. Ожидание ответа… 200 OK
# Длина: 181303310 (173M) [application/zip]
# Сохранение в: «out1.zip»
#
# out1.zip            100%[===================>] 172,90M  6,50MB/s    за 29s
#
# 2020-05-25 15:33:31 (5,95 MB/s) - «out1.zip» сохранён [181303310/181303310]

# %%
# !unzip out1.zip
# Out:
# Archive:  out1.zip
#    creating: out1/
#   inflating: out1/basket00000000.jpg
#   inflating: out1/basket00000001.jpg
#   inflating: out1/basket00000002.jpg
#   inflating: out1/basket00000003.jpg
#   inflating: out1/basket00000004.jpg
#   inflating: out1/basket00000005.jpg
#   inflating: out1/basket00000006.jpg
#   inflating: out1/basket00000007.jpg
#   inflating: out1/basket00000008.jpg
#   inflating: out1/basket00000009.jpg
#   inflating: out1/basket00000010.jpg
#   inflating: out1/basket00000011.jpg
#   inflating: out1/basket00000012.jpg
#   inflating: out1/basket00000013.jpg
#   inflating: out1/basket00000014.jpg
#   inflating: out1/basket00000015.jpg
#   inflating: out1/basket00000016.jpg
#   inflating: out1/basket00000017.jpg
#   inflating: out1/basket00000018.jpg
#   inflating: out1/basket00000019.jpg
#   inflating: out1/basket00000020.jpg
#   inflating: out1/basket00000021.jpg
#   inflating: out1/basket00000022.jpg
#   inflating: out1/basket00000023.jpg
#   inflating: out1/basket00000024.jpg
#   inflating: out1/basket00000025.jpg
#   inflating: out1/basket00000026.jpg
#   inflating: out1/basket00000027.jpg
#   inflating: out1/basket00000028.jpg
#   inflating: out1/basket00000029.jpg
#   inflating: out1/basket00000030.jpg
#   inflating: out1/basket00000031.jpg
#   inflating: out1/basket00000032.jpg
#   inflating: out1/basket00000033.jpg
#   inflating: out1/basket00000034.jpg
#   inflating: out1/basket00000035.jpg
#   inflating: out1/basket00000036.jpg
#   inflating: out1/basket00000037.jpg
#   inflating: out1/basket00000038.jpg
#   inflating: out1/basket00000039.jpg
#   inflating: out1/basket00000040.jpg
#   inflating: out1/basket00000041.jpg
#   inflating: out1/basket00000042.jpg
#   inflating: out1/basket00000043.jpg
#   inflating: out1/basket00000044.jpg
#   inflating: out1/basket00000045.jpg
#   inflating: out1/tennis00000272.jpg
#   inflating: out1/tennis00000273.jpg
#   inflating: out1/tennis00000274.jpg
#   inflating: out1/tennis00000275.jpg
#   inflating: out1/tennis00000276.jpg
#   inflating: out1/tennis00000277.jpg
#   inflating: out1/tennis00000278.jpg
#   inflating: out1/tennis00000279.jpg
#   inflating: out1/tennis00000280.jpg
#   inflating: out1/tennis00000281.jpg
#   inflating: out1/tennis00000282.jpg
#   inflating: out1/tennis00000283.jpg
#   inflating: out1/tennis00000284.jpg
#   inflating: out1/tennis00000285.jpg
#   inflating: out1/tennis00000286.jpg
#   inflating: out1/tennis00000287.jpg
#   inflating: out1/tennis00000288.jpg
#   inflating: out1/tennis00000290.jpg
#   inflating: out1/tennis00000291.jpg
#   inflating: out1/tennis00000293.jpg
#   inflating: out1/tennis00000294.jpg

# %%
import glob
img_width, img_height = 256, 256
batch_size = 64
epochs = 10
num_classes = 2

# %%
images = []
labels = []
import cv2
for image_path in glob.glob('out1/*.jpg'):
    try:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height))
        images.append(image)
        if 'basket' in image_path:
            labels.append(1)
        if 'tennis' in image_path:
            labels.append(0)
    except Exception as e:
        print(e)

# %%
x, y = 3, 3
for i in range(x*y):  
    plt.subplot(y, x, i+1)
    plt.imshow(images[i], cmap=plt.cm.gray_r, interpolation='nearest')
plt.tight_layout()
plt.show()
print(np.shape(images))
# Out:
# (640, 256, 256, 3)

# %%
images = np.array(images).astype(np.float32) / 255.0
labels = np.array(labels).astype(np.float32)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.33, random_state=42)
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
datagen = ImageDataGenerator(
    horizontal_flip = True,
    fill_mode = "nearest",
    zoom_range = 0.3,
    width_shift_range = 0.3,
    height_shift_range=0.3,
    rotation_range=30
)

# %%
from tensorflow.keras import applications
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping

model = applications.VGG19(weights = "imagenet", include_top=False, input_shape = (img_width, img_height, 3))
for layer in model.layers[:5]:
    layer.trainable = False

x = model.output
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation="relu")(x)
predictions = Dense(2, activation="softmax")(x)

model_final = Model(inputs = model.input, outputs = predictions)

model_final.compile(loss = "categorical_crossentropy", 
                    optimizer = optimizers.SGD(lr=0.0001, momentum=0.9), 
                    metrics=["accuracy"])

# %%
checkpoint = ModelCheckpoint("vgg19_1.h5", monitor='val_acc', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq=1)
early = EarlyStopping(monitor='val_acc', min_delta=0, patience=10, verbose=1, mode='auto')

# %%
model_final.fit_generator(datagen.flow(X_train, y_train,
                                       batch_size=batch_size),epochs=epochs,
                          steps_per_epoch=32,validation_data=(X_test, y_test),
                          workers=4,callbacks=[checkpoint, early])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c0f33b598e33> in <module>
# ----> 1 model_final.fit_generator(datagen.flow(X_train, y_train,
#       2                                        batch_size=batch_size),epochs=epochs,
#       3                           steps_per_epoch=32,validation_data=(X_test, y_test),
#       4                           workers=4,callbacks=[checkpoint, early])
#
# NameError: name 'model_final' is not defined

# %% [markdown]
# ## Task 5 (1 point)
#
# Prepare your dataset to be put through your model
#
# * Resize and normalize images
# * Split data in train and validation sets
# * Prepare data generator with image augmentation for training set

# %%
# Your code is here

# %% [markdown]
# ## Task 5 (1 point)
#
# * Use any pretrained model and replace dence layers
# * Freeze (make untrainable) all weight except for dence layers weights and train your model
# * Report train and validation losses
# * Unfreeze other weights, report train validation losses

# %%
# Your code is here
